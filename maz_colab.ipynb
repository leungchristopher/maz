# %% [markdown]
# # MAZ: Multiplayer AlphaZero on Colab TPU
#
# Train a 3-player Connect Four agent using AlphaZero self-play.
#
# **Setup:** Go to **Runtime → Change runtime type → TPU** before running.

# %%
# Install JAX for TPU and MAZ with colab dependencies
# !pip install -q jax[tpu] -f https://storage.googleapis.com/jax-releases/libtpu_releases.html
# !pip install -q git+https://github.com/leungchristopher/maz.git#egg=maz[colab]
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.1/155.1 MB 4.3 MB/s eta 0:00:00:00:0100:01
# DEPRECATION: git+https://github.com/yourusername/maz.git#egg=maz[colab] contains an egg fragment with a non-PEP 508 name pip 25.0 will enforce this behaviour change. A possible replacement is to use the req @ url syntax, and remove the egg fragment. Discussion can be found at https://github.com/pypa/pip/issues/11617
#   error: subprocess-exited-with-error
#
#   × git clone --filter=blob:none --quiet https://github.com/yourusername/maz.git /tmp/pip-install-xlg76r0h/maz_dca635597db5483998cef0f11cc4587a did not run successfully.
#   │ exit code: 128
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × git clone --filter=blob:none --quiet https://github.com/yourusername/maz.git /tmp/pip-install-xlg76r0h/maz_dca635597db5483998cef0f11cc4587a did not run successfully.
# │ exit code: 128
# ...

# %%
# Mount Google Drive for persistent checkpoints
from google.colab import drive
drive.mount('/content/drive')

import os
CHECKPOINT_DIR = '/content/drive/MyDrive/maz_checkpoints'
os.makedirs(CHECKPOINT_DIR, exist_ok=True)
print(f'Checkpoint dir: {CHECKPOINT_DIR}')

# %%
# Verify TPU is available
import jax
devices = jax.devices()
print(f'JAX devices ({len(devices)}): {devices}')
assert any('TPU' in str(d) for d in devices), 'No TPU found! Change runtime type.'

# %%
# Optional: log in to Weights & Biases
# Uncomment the lines below to enable W&B logging
# import wandb
# wandb.login()

# %%
# Run training (resumes automatically from last checkpoint)
from maz.main import main

main(
    checkpoint_dir=CHECKPOINT_DIR,
    use_wandb=False,  # Set to True if you logged in above
    resume=True,
)
